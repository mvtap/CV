# %% [markdown]
# <a href="https://colab.research.google.com/github/ultralytics/yolov5/blob/master/tutorial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <a align="left" href="https://ultralytics.com/yolov5" target="_blank">
# <img width="1024", src="https://user-images.githubusercontent.com/26833433/125273437-35b3fc00-e30d-11eb-9079-46f313325424.png"></a>
#
# This is the **official YOLOv5 🚀 notebook** by **Ultralytics**, and is freely available for redistribution under the [GPL-3.0 license](https://choosealicense.com/licenses/gpl-3.0/).
# For more information please visit https://github.com/ultralytics/yolov5 and https://ultralytics.com. Thank you!

# %% [markdown]
# # Setup
#
# Clone repo, install dependencies and check PyTorch and GPU.

# %%
#!git clone https://github.com/ultralytics/yolov5  # clone
# %cd yolov5
#%pip install -qr requirements.txt  # install

import torch
from yolov5 import utils
display = utils.notebook_init()  # checks
# Out:
# [Errno 2] No such file or directory: 'yolov5'
# /home/miguel/Documents/Git/CV/code
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-e6ad6e313d95> in <module>
#       4
#       5 import torch
# ----> 6 from yolov5 import utils
#       7 display = utils.notebook_init()  # checks
#
# ModuleNotFoundError: No module named 'yolov5'

# %% [markdown]
# # 1. Inference
#
# `detect.py` runs YOLOv5 inference on a variety of sources, downloading models automatically from the [latest YOLOv5 release](https://github.com/ultralytics/yolov5/releases), and saving results to `runs/detect`. Example inference sources are:
#
# ```shell
# python detect.py --source 0  # webcam
#                           img.jpg  # image
#                           vid.mp4  # video
#                           path/  # directory
#                           path/*.jpg  # glob
#                           'https://youtu.be/Zgi9g1ksQHc'  # YouTube
#                           'rtsp://example.com/media.mp4'  # RTSP, RTMP, HTTP stream
# ```

# %%
# !python3 detect.py --weights runs/train/exp5/weights/best.pt --img 640 --conf 0.40 --source ../2-D2640_small.mp4
# Out:
# detect: weights=['runs/train/exp5/weights/best.pt'], source=../2-D2640_small.mp4, imgsz=[640, 640], conf_thres=0.4, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 e9f4fe6 torch 1.10.0+cu102 CUDA:0 (GeForce GTX 970, 4040MiB)
#
# Fusing layers...
# Model Summary: 290 layers, 20861016 parameters, 0 gradients, 48.0 GFLOPs
# video 1/1 (1/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.022s)
# video 1/1 (2/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.020s)
# video 1/1 (3/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.020s)
# video 1/1 (4/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.021s)
# video 1/1 (5/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.021s)
# video 1/1 (6/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.020s)
# video 1/1 (7/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.019s)
# video 1/1 (8/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.018s)
# video 1/1 (9/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.018s)
# video 1/1 (10/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.020s)
# video 1/1 (11/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.018s)
# video 1/1 (12/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.019s)
# video 1/1 (13/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.018s)
# video 1/1 (14/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (15/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.018s)
# video 1/1 (16/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (17/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (18/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (19/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.018s)
# video 1/1 (20/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (21/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.018s)
# video 1/1 (22/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (23/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.018s)
# video 1/1 (24/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (25/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (26/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.018s)
# video 1/1 (27/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (28/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.018s)
# video 1/1 (29/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (30/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (31/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (32/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (33/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.018s)
# video 1/1 (34/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (35/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (36/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (37/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (38/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.018s)
# video 1/1 (39/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (40/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.018s)
# video 1/1 (41/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (42/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (43/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.018s)
# video 1/1 (44/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (45/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.018s)
# video 1/1 (46/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (47/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (48/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.018s)
# video 1/1 (49/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (50/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.018s)
# video 1/1 (51/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (52/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (53/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.018s)
# video 1/1 (54/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (55/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.018s)
# video 1/1 (56/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.018s)
# video 1/1 (57/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (58/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.018s)
# video 1/1 (59/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (60/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.018s)
# video 1/1 (61/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (62/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (63/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.018s)
# video 1/1 (64/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (65/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.018s)
# video 1/1 (66/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.018s)
# video 1/1 (67/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (68/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (69/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (70/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.018s)
# video 1/1 (71/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (72/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (73/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (74/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (75/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (76/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (77/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.018s)
# video 1/1 (78/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.018s)
# video 1/1 (79/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (80/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (81/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (82/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (83/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.018s)
# video 1/1 (84/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (85/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (86/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (87/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (88/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.018s)
# video 1/1 (89/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (90/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (91/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (92/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (93/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.018s)
# video 1/1 (94/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (95/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (96/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (97/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (98/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.018s)
# video 1/1 (99/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (100/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.018s)
# video 1/1 (101/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (102/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (103/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.018s)
# video 1/1 (104/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (105/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.018s)
# video 1/1 (106/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (107/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (108/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.018s)
# video 1/1 (109/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (110/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (111/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (112/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (113/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.018s)
# video 1/1 (114/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (115/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (116/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.018s)
# video 1/1 (117/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (118/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.018s)
# video 1/1 (119/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (120/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.018s)
# video 1/1 (121/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (122/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (123/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (124/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (125/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.018s)
# video 1/1 (126/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (127/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (128/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (129/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (130/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.018s)
# video 1/1 (131/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (132/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (133/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.018s)
# video 1/1 (134/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (135/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (136/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.018s)
# video 1/1 (137/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (138/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.018s)
# video 1/1 (139/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (140/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (141/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.018s)
# video 1/1 (142/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.016s)
# video 1/1 (143/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.018s)
# video 1/1 (144/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (145/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (146/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.018s)
# video 1/1 (147/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (148/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.018s)
# video 1/1 (149/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (150/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (151/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (152/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (153/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.018s)
# video 1/1 (154/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (155/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (156/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.016s)
# video 1/1 (157/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (158/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (159/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (160/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (161/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (162/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (163/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (164/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (165/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (166/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (167/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (168/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.018s)
# video 1/1 (169/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (170/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (171/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (172/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (173/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (174/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (175/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (176/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (177/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 1 main signal, Done. (0.017s)
# video 1/1 (178/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 1 main signal, Done. (0.017s)
# video 1/1 (179/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 1 main signal, Done. (0.018s)
# video 1/1 (180/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 1 main signal, Done. (0.019s)
# video 1/1 (181/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 1 main signal, Done. (0.019s)
# video 1/1 (182/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 1 main signal, Done. (0.018s)
# video 1/1 (183/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 1 main signal, Done. (0.019s)
# video 1/1 (184/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 1 main signal, Done. (0.019s)
# video 1/1 (185/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.019s)
# video 1/1 (186/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.018s)
# video 1/1 (187/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (188/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 1 main signal, Done. (0.017s)
# video 1/1 (189/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 1 main signal, Done. (0.018s)
# video 1/1 (190/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 1 main signal, Done. (0.017s)
# video 1/1 (191/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 1 main signal, Done. (0.018s)
# video 1/1 (192/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (193/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 1 main signal, Done. (0.017s)
# video 1/1 (194/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 1 main signal, Done. (0.017s)
# video 1/1 (195/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 1 main signal, Done. (0.017s)
# video 1/1 (196/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 1 main signal, Done. (0.017s)
# video 1/1 (197/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 1 main signal, Done. (0.017s)
# video 1/1 (198/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 1 main signal, Done. (0.018s)
# video 1/1 (199/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 1 main signal, Done. (0.017s)
# video 1/1 (200/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 1 main signal, Done. (0.018s)
# video 1/1 (201/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 1 main signal, Done. (0.017s)
# video 1/1 (202/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 1 main signal, Done. (0.017s)
# video 1/1 (203/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 1 main signal, Done. (0.017s)
# video 1/1 (204/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 1 main signal, Done. (0.019s)
# video 1/1 (205/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 1 main signal, Done. (0.018s)
# video 1/1 (206/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 1 main signal, Done. (0.019s)
# video 1/1 (207/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 1 main signal, Done. (0.019s)
# video 1/1 (208/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 1 main signal, Done. (0.017s)
# video 1/1 (209/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 1 main signal, Done. (0.018s)
# video 1/1 (210/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 1 main signal, Done. (0.018s)
# video 1/1 (211/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 1 main signal, Done. (0.017s)
# video 1/1 (212/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 1 main signal, Done. (0.018s)
# video 1/1 (213/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 1 main signal, Done. (0.018s)
# video 1/1 (214/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 1 main signal, Done. (0.017s)
# video 1/1 (215/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 1 main signal, Done. (0.017s)
# video 1/1 (216/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 1 main signal, Done. (0.018s)
# video 1/1 (217/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 1 main signal, Done. (0.017s)
# video 1/1 (218/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 1 main signal, Done. (0.018s)
# video 1/1 (219/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 1 main signal, Done. (0.017s)
# video 1/1 (220/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 1 main signal, Done. (0.018s)
# video 1/1 (221/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 1 main signal, Done. (0.017s)
# video 1/1 (222/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 1 main signal, Done. (0.017s)
# video 1/1 (223/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 1 main signal, Done. (0.017s)
# video 1/1 (224/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 1 main signal, Done. (0.017s)
# video 1/1 (225/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 1 main signal, Done. (0.018s)
# video 1/1 (226/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 1 main signal, Done. (0.017s)
# video 1/1 (227/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 1 main signal, Done. (0.018s)
# video 1/1 (228/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 1 main signal, Done. (0.017s)
# video 1/1 (229/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 1 main signal, Done. (0.018s)
# video 1/1 (230/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 1 main signal, Done. (0.017s)
# video 1/1 (231/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 1 main signal, Done. (0.017s)
# video 1/1 (232/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 1 main signal, Done. (0.017s)
# video 1/1 (233/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 1 main signal, Done. (0.017s)
# video 1/1 (234/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 1 main signal, Done. (0.018s)
# video 1/1 (235/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 1 main signal, Done. (0.017s)
# video 1/1 (236/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 1 main signal, Done. (0.018s)
# video 1/1 (237/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 1 main signal, Done. (0.017s)
# video 1/1 (238/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 1 main signal, Done. (0.017s)
# video 1/1 (239/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 1 main signal, Done. (0.018s)
# video 1/1 (240/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 1 main signal, Done. (0.017s)
# video 1/1 (241/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 1 main signal, Done. (0.017s)
# video 1/1 (242/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 1 main signal, Done. (0.017s)
# video 1/1 (243/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 1 main signal, Done. (0.017s)
# video 1/1 (244/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 1 main signal, 1 distant signal, Done. (0.018s)
# video 1/1 (245/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 1 main signal, 1 distant signal, Done. (0.017s)
# video 1/1 (246/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 1 main signal, 1 distant signal, Done. (0.018s)
# video 1/1 (247/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 1 main signal, 1 distant signal, Done. (0.017s)
# video 1/1 (248/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 1 main signal, 1 distant signal, Done. (0.018s)
# video 1/1 (249/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 1 main signal, 1 distant signal, Done. (0.017s)
# video 1/1 (250/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 1 main signal, 1 distant signal, Done. (0.017s)
# video 1/1 (251/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 1 main signal, 1 distant signal, Done. (0.017s)
# video 1/1 (252/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 1 main signal, 1 distant signal, Done. (0.017s)
# video 1/1 (253/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 1 main signal, 1 distant signal, Done. (0.019s)
# video 1/1 (254/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 1 main signal, 1 distant signal, Done. (0.017s)
# video 1/1 (255/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 1 main signal, 1 distant signal, Done. (0.018s)
# video 1/1 (256/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 1 main signal, 1 distant signal, Done. (0.017s)
# video 1/1 (257/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 1 main signal, 1 distant signal, Done. (0.018s)
# video 1/1 (258/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 1 main signal, 1 distant signal, Done. (0.017s)
# video 1/1 (259/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 1 main signal, 1 distant signal, Done. (0.018s)
# video 1/1 (260/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 1 main signal, 1 distant signal, Done. (0.017s)
# video 1/1 (261/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 1 main signal, 1 distant signal, Done. (0.017s)
# video 1/1 (262/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 1 main signal, 1 distant signal, Done. (0.017s)
# video 1/1 (263/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 1 main signal, 1 distant signal, Done. (0.017s)
# video 1/1 (264/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 1 main signal, 1 distant signal, Done. (0.017s)
# video 1/1 (265/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 1 main signal, 1 distant signal, Done. (0.017s)
# video 1/1 (266/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 1 main signal, 1 distant signal, Done. (0.018s)
# video 1/1 (267/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 1 main signal, 1 distant signal, Done. (0.017s)
# video 1/1 (268/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 1 main signal, 1 distant signal, Done. (0.018s)
# video 1/1 (269/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 1 main signal, 1 distant signal, Done. (0.017s)
# video 1/1 (270/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 1 main signal, 1 distant signal, Done. (0.017s)
# video 1/1 (271/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 1 main signal, 1 distant signal, Done. (0.017s)
# video 1/1 (272/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 1 main signal, 1 distant signal, Done. (0.017s)
# video 1/1 (273/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 1 main signal, 1 distant signal, Done. (0.017s)
# video 1/1 (274/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 1 main signal, 1 distant signal, Done. (0.017s)
# video 1/1 (275/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 1 main signal, 1 distant signal, Done. (0.018s)
# video 1/1 (276/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 1 main signal, 1 distant signal, Done. (0.017s)
# video 1/1 (277/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 1 main signal, 1 distant signal, Done. (0.017s)
# video 1/1 (278/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 1 main signal, 1 distant signal, Done. (0.017s)
# video 1/1 (279/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 1 main signal, 1 distant signal, Done. (0.018s)
# video 1/1 (280/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 1 main signal, 1 distant signal, Done. (0.017s)
# video 1/1 (281/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 1 main signal, 1 distant signal, Done. (0.017s)
# video 1/1 (282/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 1 distant signal, Done. (0.017s)
# video 1/1 (283/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 1 distant signal, Done. (0.017s)
# video 1/1 (284/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 1 distant signal, Done. (0.018s)
# video 1/1 (285/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 1 distant signal, Done. (0.017s)
# video 1/1 (286/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 1 distant signal, Done. (0.018s)
# video 1/1 (287/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 1 distant signal, Done. (0.017s)
# video 1/1 (288/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 1 distant signal, Done. (0.017s)
# video 1/1 (289/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 1 distant signal, Done. (0.017s)
# video 1/1 (290/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 1 distant signal, Done. (0.017s)
# video 1/1 (291/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 1 distant signal, Done. (0.018s)
# video 1/1 (292/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 1 distant signal, Done. (0.017s)
# video 1/1 (293/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 1 distant signal, Done. (0.018s)
# video 1/1 (294/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (295/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (296/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.018s)
# video 1/1 (297/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (298/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.018s)
# video 1/1 (299/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (300/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.018s)
# video 1/1 (301/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (302/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (303/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (304/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (305/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (306/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.018s)
# video 1/1 (307/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (308/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (309/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.016s)
# video 1/1 (310/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (311/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.018s)
# video 1/1 (312/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (313/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (314/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (315/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (316/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (317/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.018s)
# video 1/1 (318/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (319/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (320/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (321/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.018s)
# video 1/1 (322/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (323/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.018s)
# video 1/1 (324/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (325/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (326/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.018s)
# video 1/1 (327/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (328/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.018s)
# video 1/1 (329/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (330/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (331/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.018s)
# video 1/1 (332/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (333/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.018s)
# video 1/1 (334/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (335/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (336/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.018s)
# video 1/1 (337/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (338/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.018s)
# video 1/1 (339/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (340/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (341/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.018s)
# video 1/1 (342/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (343/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.018s)
# video 1/1 (344/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (345/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (346/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (347/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (348/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (349/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.018s)
# video 1/1 (350/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (351/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (352/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (353/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (354/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (355/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (356/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.018s)
# video 1/1 (357/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (358/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (359/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.018s)
# video 1/1 (360/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (361/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.018s)
# video 1/1 (362/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (363/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (364/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.018s)
# video 1/1 (365/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (366/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.018s)
# video 1/1 (367/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (368/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (369/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (370/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (371/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.018s)
# video 1/1 (372/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (373/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (374/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (375/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (376/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.018s)
# video 1/1 (377/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (378/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (379/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (380/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (381/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.018s)
# video 1/1 (382/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (383/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (384/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (385/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (386/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.018s)
# video 1/1 (387/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (388/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (389/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (390/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (391/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.018s)
# video 1/1 (392/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (393/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (394/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (395/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (396/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.018s)
# video 1/1 (397/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (398/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (399/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (400/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (401/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.018s)
# video 1/1 (402/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (403/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (404/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (405/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (406/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (407/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (408/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (409/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (410/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (411/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.018s)
# video 1/1 (412/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (413/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (414/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (415/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (416/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (417/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.018s)
# video 1/1 (418/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (419/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (420/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (421/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (422/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.018s)
# video 1/1 (423/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (424/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.018s)
# video 1/1 (425/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (426/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (427/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.018s)
# video 1/1 (428/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (429/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.018s)
# video 1/1 (430/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (431/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (432/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.018s)
# video 1/1 (433/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (434/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.018s)
# video 1/1 (435/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (436/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (437/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.018s)
# video 1/1 (438/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (439/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.018s)
# video 1/1 (440/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (441/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (442/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.018s)
# video 1/1 (443/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (444/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (445/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (446/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (447/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.018s)
# video 1/1 (448/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (449/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.018s)
# video 1/1 (450/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (451/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (452/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.018s)
# video 1/1 (453/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (454/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.018s)
# video 1/1 (455/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (456/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (457/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.019s)
# video 1/1 (458/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (459/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.018s)
# video 1/1 (460/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.018s)
# video 1/1 (461/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.018s)
# video 1/1 (462/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (463/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.018s)
# video 1/1 (464/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.018s)
# video 1/1 (465/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (466/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.018s)
# video 1/1 (467/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.018s)
# video 1/1 (468/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.018s)
# video 1/1 (469/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (470/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.018s)
# video 1/1 (471/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (472/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (473/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (474/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (475/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (476/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.018s)
# video 1/1 (477/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (478/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.018s)
# video 1/1 (479/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (480/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (481/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.018s)
# video 1/1 (482/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (483/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.018s)
# video 1/1 (484/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# ...
# video 1/1 (1649/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 1 main signal, Done. (0.017s)
# video 1/1 (1650/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 1 main signal, Done. (0.018s)
# video 1/1 (1651/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 1 main signal, Done. (0.017s)
# video 1/1 (1652/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (1653/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (1654/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (1655/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.018s)
# video 1/1 (1656/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (1657/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (1658/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (1659/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (1660/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.018s)
# video 1/1 (1661/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (1662/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (1663/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (1664/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (1665/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.018s)
# video 1/1 (1666/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (1667/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (1668/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (1669/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (1670/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.018s)
# video 1/1 (1671/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (1672/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.018s)
# video 1/1 (1673/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (1674/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (1675/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.018s)
# video 1/1 (1676/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (1677/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.018s)
# video 1/1 (1678/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (1679/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (1680/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.018s)
# video 1/1 (1681/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (1682/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 1 main signal, Done. (0.018s)
# video 1/1 (1683/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (1684/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (1685/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.018s)
# video 1/1 (1686/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (1687/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 1 main signal, Done. (0.018s)
# video 1/1 (1688/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 1 main signal, Done. (0.017s)
# video 1/1 (1689/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 1 main signal, Done. (0.017s)
# video 1/1 (1690/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 1 main signal, Done. (0.017s)
# video 1/1 (1691/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 1 main signal, Done. (0.017s)
# video 1/1 (1692/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (1693/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 1 main signal, Done. (0.017s)
# video 1/1 (1694/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 1 main signal, Done. (0.017s)
# video 1/1 (1695/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 1 main signal, Done. (0.018s)
# video 1/1 (1696/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 1 main signal, Done. (0.017s)
# video 1/1 (1697/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 1 main signal, Done. (0.018s)
# video 1/1 (1698/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 1 main signal, Done. (0.017s)
# video 1/1 (1699/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 1 main signal, Done. (0.017s)
# video 1/1 (1700/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 1 main signal, Done. (0.017s)
# video 1/1 (1701/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 1 main signal, Done. (0.017s)
# video 1/1 (1702/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 1 main signal, Done. (0.018s)
# video 1/1 (1703/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 1 main signal, Done. (0.017s)
# video 1/1 (1704/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 1 main signal, Done. (0.018s)
# video 1/1 (1705/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 1 main signal, Done. (0.017s)
# video 1/1 (1706/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 1 main signal, Done. (0.017s)
# video 1/1 (1707/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 1 main signal, Done. (0.018s)
# video 1/1 (1708/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 2 main signals, Done. (0.017s)
# video 1/1 (1709/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 2 main signals, Done. (0.017s)
# video 1/1 (1710/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 2 main signals, Done. (0.017s)
# video 1/1 (1711/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 2 main signals, Done. (0.018s)
# video 1/1 (1712/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 2 main signals, Done. (0.017s)
# video 1/1 (1713/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 2 main signals, Done. (0.018s)
# video 1/1 (1714/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 2 main signals, Done. (0.017s)
# video 1/1 (1715/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 1 main signal, Done. (0.018s)
# video 1/1 (1716/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 1 main signal, Done. (0.017s)
# video 1/1 (1717/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 2 main signals, Done. (0.017s)
# video 1/1 (1718/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 2 main signals, Done. (0.017s)
# video 1/1 (1719/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 2 main signals, Done. (0.017s)
# video 1/1 (1720/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 1 main signal, Done. (0.017s)
# video 1/1 (1721/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 1 main signal, Done. (0.017s)
# video 1/1 (1722/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 1 main signal, Done. (0.017s)
# video 1/1 (1723/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 2 main signals, Done. (0.017s)
# video 1/1 (1724/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 2 main signals, Done. (0.017s)
# video 1/1 (1725/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 2 main signals, Done. (0.017s)
# video 1/1 (1726/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 2 main signals, Done. (0.017s)
# video 1/1 (1727/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 1 main signal, Done. (0.017s)
# video 1/1 (1728/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 1 main signal, Done. (0.017s)
# video 1/1 (1729/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 2 main signals, Done. (0.017s)
# video 1/1 (1730/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 2 main signals, Done. (0.018s)
# video 1/1 (1731/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 2 main signals, Done. (0.018s)
# video 1/1 (1732/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 2 main signals, Done. (0.018s)
# video 1/1 (1733/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 2 main signals, Done. (0.017s)
# video 1/1 (1734/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 2 main signals, Done. (0.018s)
# video 1/1 (1735/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 2 main signals, Done. (0.017s)
# video 1/1 (1736/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 2 main signals, Done. (0.018s)
# video 1/1 (1737/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 2 main signals, Done. (0.017s)
# video 1/1 (1738/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 2 main signals, Done. (0.017s)
# video 1/1 (1739/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 2 main signals, Done. (0.017s)
# video 1/1 (1740/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 2 main signals, Done. (0.017s)
# video 1/1 (1741/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 2 main signals, Done. (0.018s)
# video 1/1 (1742/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 2 main signals, Done. (0.017s)
# video 1/1 (1743/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 2 main signals, Done. (0.018s)
# video 1/1 (1744/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 1 main signal, Done. (0.017s)
# video 1/1 (1745/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 1 main signal, Done. (0.017s)
# video 1/1 (1746/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 1 main signal, Done. (0.017s)
# video 1/1 (1747/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 1 main signal, Done. (0.017s)
# video 1/1 (1748/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 1 main signal, Done. (0.018s)
# video 1/1 (1749/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 1 main signal, Done. (0.017s)
# video 1/1 (1750/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 1 main signal, Done. (0.017s)
# video 1/1 (1751/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 1 main signal, Done. (0.018s)
# video 1/1 (1752/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 1 main signal, Done. (0.017s)
# video 1/1 (1753/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 1 main signal, Done. (0.017s)
# video 1/1 (1754/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 1 main signal, Done. (0.017s)
# video 1/1 (1755/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 1 main signal, Done. (0.017s)
# video 1/1 (1756/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 1 main signal, Done. (0.018s)
# video 1/1 (1757/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 1 main signal, Done. (0.018s)
# video 1/1 (1758/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 1 main signal, Done. (0.017s)
# video 1/1 (1759/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 1 main signal, Done. (0.018s)
# video 1/1 (1760/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 1 main signal, Done. (0.017s)
# video 1/1 (1761/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 1 main signal, Done. (0.017s)
# video 1/1 (1762/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 1 main signal, Done. (0.017s)
# video 1/1 (1763/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 1 main signal, Done. (0.017s)
# video 1/1 (1764/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 1 main signal, Done. (0.018s)
# video 1/1 (1765/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 1 main signal, Done. (0.017s)
# video 1/1 (1766/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 1 main signal, Done. (0.018s)
# video 1/1 (1767/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 1 traffic light, 1 main signal, Done. (0.017s)
# video 1/1 (1768/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 1 main signal, Done. (0.018s)
# video 1/1 (1769/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 1 main signal, Done. (0.017s)
# video 1/1 (1770/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 1 main signal, Done. (0.017s)
# video 1/1 (1771/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 1 main signal, Done. (0.018s)
# video 1/1 (1772/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.018s)
# video 1/1 (1773/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.018s)
# video 1/1 (1774/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (1775/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.023s)
# video 1/1 (1776/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.023s)
# video 1/1 (1777/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.022s)
# video 1/1 (1778/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 1 main signal, Done. (0.020s)
# video 1/1 (1779/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 1 main signal, Done. (0.032s)
# video 1/1 (1780/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.021s)
# video 1/1 (1781/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.018s)
# video 1/1 (1782/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.020s)
# video 1/1 (1783/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.018s)
# video 1/1 (1784/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (1785/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.018s)
# video 1/1 (1786/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (1787/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (1788/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.018s)
# video 1/1 (1789/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (1790/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.018s)
# video 1/1 (1791/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (1792/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.019s)
# video 1/1 (1793/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (1794/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (1795/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.018s)
# video 1/1 (1796/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (1797/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (1798/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.018s)
# video 1/1 (1799/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (1800/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (1801/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# video 1/1 (1802/1802) /home/miguel/Documents/Git/CV/2-D2640_small.mp4: 352x640 Done. (0.017s)
# Speed: 0.3ms pre-process, 17.5ms inference, 0.5ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp32

# %%
# !python3 detect.py --weights runs/train/exp5/weights/best.pt --img 640 --conf 0.50 --source ../2-D2640_short.mp4

# %%
# !python3 detect.py --weights runs/train/Colab/best.pt --img 640 --conf 0.40 --source ../2-D2640.mp4

# %%
# !python3 detect.py --weights runs/train/Colab/best.pt --img 640 --conf 0.40 --source ../2-D2640_part1.mp4

# %%
# !python3 detect.py --weights runs/train/Colab/best.pt --img 640 --conf 0.40 --source ../3-N7910_part1.mp4

# %%
# !python3 detect.py --weights runs/train/Colab/best.pt --img 640 --conf 0.40 --source ../3-N7910_part2.mp4

# %%
# !python3 detect.py --weights runs/train/Colab/best.pt --img 640 --conf 0.25 --source ../real_5-6m.mp4

# %%
# !python3 detect.py --weights runs/train/Colab/best.pt --img 640 --conf 0.25 --source ../real_26-27m.mp4

# %%
# !python3 detect.py --weights runs/train/Colab/best.pt --img 640 --conf 0.25 --source ../real_29-30m.mp4

# %% [markdown]
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <img align="left" src="https://user-images.githubusercontent.com/26833433/127574988-6a558aa1-d268-44b9-bf6b-62d4c605cc72.jpg" width="600">

# %% [markdown]
# # 2. Validate
# Validate a model's accuracy on [COCO](https://cocodataset.org/#home) val or test-dev datasets. Models are downloaded automatically from the [latest YOLOv5 release](https://github.com/ultralytics/yolov5/releases). To show results by class use the `--verbose` flag. Note that `pycocotools` metrics may be ~1% better than the equivalent repo metrics, as is visible below, due to slight differences in mAP computation.

# %% [markdown]
# ## COCO val
# Download [COCO val 2017](https://github.com/ultralytics/yolov5/blob/74b34872fdf41941cddcf243951cdb090fbac17b/data/coco.yaml#L14) dataset (1GB - 5000 images), and test model accuracy.

# %%
# Download COCO val
torch.hub.download_url_to_file('https://ultralytics.com/assets/coco2017val.zip', 'tmp.zip')
# !unzip -q tmp.zip -d ../datasets && rm tmp.zip

# %%
# Run YOLOv5x on COCO val
# !python val.py --weights yolov5x.pt --data coco.yaml --img 640 --iou 0.65 --half

# %% [markdown]
# ## COCO test
# Download [COCO test2017](https://github.com/ultralytics/yolov5/blob/74b34872fdf41941cddcf243951cdb090fbac17b/data/coco.yaml#L15) dataset (7GB - 40,000 images), to test model accuracy on test-dev set (**20,000 images, no labels**). Results are saved to a `*.json` file which should be **zipped** and submitted to the evaluation server at https://competitions.codalab.org/competitions/20794.

# %%
# Download COCO test-dev2017
torch.hub.download_url_to_file('https://ultralytics.com/assets/coco2017labels.zip', 'tmp.zip')
# !unzip -q tmp.zip -d ../datasets && rm tmp.zip
# !f="test2017.zip" && curl http://images.cocodataset.org/zips/$f -o $f && unzip -q $f -d ../datasets/coco/images

# %%
# Run YOLOv5x on COCO test
# !python val.py --weights yolov5x.pt --data coco.yaml --img 640 --iou 0.65 --half --task test

# %% [markdown]
# # 3. Train
#
# <p align=""><a href="https://roboflow.com/?ref=ultralytics"><img width="1000" src="https://uploads-ssl.webflow.com/5f6bc60e665f54545a1e52a5/615627e5824c9c6195abfda9_computer-vision-cycle.png"/></a></p>
# Close the active learning loop by sampling images from your inference conditions with the `roboflow` pip package
# <br><br>
#
# Train a YOLOv5s model on the [COCO128](https://www.kaggle.com/ultralytics/coco128) dataset with `--data coco128.yaml`, starting from pretrained `--weights yolov5s.pt`, or from randomly initialized `--weights '' --cfg yolov5s.yaml`.
#
# - **Pretrained [Models](https://github.com/ultralytics/yolov5/tree/master/models)** are downloaded
# automatically from the [latest YOLOv5 release](https://github.com/ultralytics/yolov5/releases)
# - **[Datasets](https://github.com/ultralytics/yolov5/tree/master/data)** available for autodownload include: [COCO](https://github.com/ultralytics/yolov5/blob/master/data/coco.yaml), [COCO128](https://github.com/ultralytics/yolov5/blob/master/data/coco128.yaml), [VOC](https://github.com/ultralytics/yolov5/blob/master/data/VOC.yaml), [Argoverse](https://github.com/ultralytics/yolov5/blob/master/data/Argoverse.yaml), [VisDrone](https://github.com/ultralytics/yolov5/blob/master/data/VisDrone.yaml), [GlobalWheat](https://github.com/ultralytics/yolov5/blob/master/data/GlobalWheat2020.yaml), [xView](https://github.com/ultralytics/yolov5/blob/master/data/xView.yaml), [Objects365](https://github.com/ultralytics/yolov5/blob/master/data/Objects365.yaml), [SKU-110K](https://github.com/ultralytics/yolov5/blob/master/data/SKU-110K.yaml).
# - **Training Results** are saved to `runs/train/` with incrementing run directories, i.e. `runs/train/exp2`, `runs/train/exp3` etc.
# <br><br>
#
# ## Train on Custom Data with Roboflow 🌟 NEW
#
# [Roboflow](https://roboflow.com/?ref=ultralytics) enables you to easily **organize, label, and prepare** a high quality dataset with your own custom data. Roboflow also makes it easy to establish an active learning pipeline, collaborate with your team on dataset improvement, and integrate directly into your model building workflow with the `roboflow` pip package.
#
# - Custom Training Example: [https://blog.roboflow.com/how-to-train-yolov5-on-a-custom-dataset/](https://blog.roboflow.com/how-to-train-yolov5-on-a-custom-dataset/?ref=ultralytics)
# - Custom Training Notebook: [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/roboflow-ai/yolov5-custom-training-tutorial/blob/main/yolov5-custom-training.ipynb)
# <br>
#
# <p align=""><a href="https://roboflow.com/?ref=ultralytics"><img width="480" src="https://uploads-ssl.webflow.com/5f6bc60e665f54545a1e52a5/6152a275ad4b4ac20cd2e21a_roboflow-annotate.gif"/></a></p>Label images lightning fast (including with model-assisted labeling)

# %%
# Tensorboard  (optional)
# %load_ext tensorboard
# %tensorboard --logdir runs/train

# %%
# Weights & Biases  (optional)
# %pip install -q wandb
import wandb
wandb.login()

# %%
# Train YOLOv5s on COCO128 for 3 epochs
# !python3 train.py --img 640 --batch 8 --epochs 300 --data coco128.yaml --weights yolov5m.pt --cache

# %% [markdown]
# # 4. Visualize

# %% [markdown]
# ## Weights & Biases Logging 🌟 NEW
#
# [Weights & Biases](https://wandb.ai/site?utm_campaign=repo_yolo_notebook) (W&B) is now integrated with YOLOv5 for real-time visualization and cloud logging of training runs. This allows for better run comparison and introspection, as well improved visibility and collaboration for teams. To enable W&B `pip install wandb`, and then train normally (you will be guided through setup on first use).
#
# During training you will see live updates at [https://wandb.ai/home](https://wandb.ai/home?utm_campaign=repo_yolo_notebook), and you can create and share detailed [Reports](https://wandb.ai/glenn-jocher/yolov5_tutorial/reports/YOLOv5-COCO128-Tutorial-Results--VmlldzozMDI5OTY) of your results. For more information see the [YOLOv5 Weights & Biases Tutorial](https://github.com/ultralytics/yolov5/issues/1289).
#
# <p align="left"><img width="900" alt="Weights & Biases dashboard" src="https://user-images.githubusercontent.com/26833433/135390767-c28b050f-8455-4004-adb0-3b730386e2b2.png"></p>

# %% [markdown]
# ## Local Logging
#
# All results are logged by default to `runs/train`, with a new experiment directory created for each new training as `runs/train/exp2`, `runs/train/exp3`, etc. View train and val jpgs to see mosaics, labels, predictions and augmentation effects. Note an Ultralytics **Mosaic Dataloader** is used for training (shown below), which combines 4 images into 1 mosaic during training.
#
# > <img src="https://user-images.githubusercontent.com/26833433/131255960-b536647f-7c61-4f60-bbc5-cb2544d71b2a.jpg" width="700">
# `train_batch0.jpg` shows train batch 0 mosaics and labels
#
# > <img src="https://user-images.githubusercontent.com/26833433/131256748-603cafc7-55d1-4e58-ab26-83657761aed9.jpg" width="700">
# `test_batch0_labels.jpg` shows val batch 0 labels
#
# > <img src="https://user-images.githubusercontent.com/26833433/131256752-3f25d7a5-7b0f-4bb3-ab78-46343c3800fe.jpg" width="700">
# `test_batch0_pred.jpg` shows val batch 0 _predictions_
#
# Training results are automatically logged to [Tensorboard](https://www.tensorflow.org/tensorboard) and [CSV](https://github.com/ultralytics/yolov5/pull/4148) as `results.csv`, which is plotted as `results.png` (below) after training completes. You can also plot any `results.csv` file manually:
#
# ```python
# from utils.plots import plot_results
# plot_results('path/to/results.csv')  # plot 'results.csv' as 'results.png'
# ```
#
# <img align="left" width="800" alt="COCO128 Training Results" src="https://user-images.githubusercontent.com/26833433/126906780-8c5e2990-6116-4de6-b78a-367244a33ccf.png">

# %% [markdown]
# # Environments
#
# YOLOv5 may be run in any of the following up-to-date verified environments (with all dependencies including [CUDA](https://developer.nvidia.com/cuda)/[CUDNN](https://developer.nvidia.com/cudnn), [Python](https://www.python.org/) and [PyTorch](https://pytorch.org/) preinstalled):
#
# - **Google Colab and Kaggle** notebooks with free GPU: <a href="https://colab.research.google.com/github/ultralytics/yolov5/blob/master/tutorial.ipynb"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"></a> <a href="https://www.kaggle.com/ultralytics/yolov5"><img src="https://kaggle.com/static/images/open-in-kaggle.svg" alt="Open In Kaggle"></a>
# - **Google Cloud** Deep Learning VM. See [GCP Quickstart Guide](https://github.com/ultralytics/yolov5/wiki/GCP-Quickstart)
# - **Amazon** Deep Learning AMI. See [AWS Quickstart Guide](https://github.com/ultralytics/yolov5/wiki/AWS-Quickstart)
# - **Docker Image**. See [Docker Quickstart Guide](https://github.com/ultralytics/yolov5/wiki/Docker-Quickstart) <a href="https://hub.docker.com/r/ultralytics/yolov5"><img src="https://img.shields.io/docker/pulls/ultralytics/yolov5?logo=docker" alt="Docker Pulls"></a>

# %% [markdown]
# # Status
#
# ![CI CPU testing](https://github.com/ultralytics/yolov5/workflows/CI%20CPU%20testing/badge.svg)
#
# If this badge is green, all [YOLOv5 GitHub Actions](https://github.com/ultralytics/yolov5/actions) Continuous Integration (CI) tests are currently passing. CI tests verify correct operation of YOLOv5 training ([train.py](https://github.com/ultralytics/yolov5/blob/master/train.py)), testing ([val.py](https://github.com/ultralytics/yolov5/blob/master/val.py)), inference ([detect.py](https://github.com/ultralytics/yolov5/blob/master/detect.py)) and export ([export.py](https://github.com/ultralytics/yolov5/blob/master/export.py)) on MacOS, Windows, and Ubuntu every 24 hours and on every commit.

# %% [markdown]
# # Appendix
#
# Optional extras below. Unit tests validate repo functionality and should be run on any PRs submitted.

# %%
# Reproduce
for x in 'yolov5s', 'yolov5m', 'yolov5l', 'yolov5x':
  # !python val.py --weights {x}.pt --data coco.yaml --img 640 --task speed  # speed
  # !python val.py --weights {x}.pt --data coco.yaml --img 640 --conf 0.001 --iou 0.65  # mAP

# %%
# PyTorch Hub
import torch

# Model
model = torch.hub.load('ultralytics/yolov5', 'yolov5s')

# Images
dir = 'https://ultralytics.com/images/'
imgs = [dir + f for f in ('zidane.jpg', 'bus.jpg')]  # batch of images

# Inference
results = model(imgs)
results.print()  # or .show(), .save()

# %%
# CI Checks
# %%shell
export PYTHONPATH="$PWD"  # to run *.py. files in subdirectories
rm -rf runs  # remove runs/
for m in yolov5n; do  # models
  python train.py --img 64 --batch 32 --weights $m.pt --epochs 1 --device 0  # train pretrained
  python train.py --img 64 --batch 32 --weights '' --cfg $m.yaml --epochs 1 --device 0  # train scratch
  for d in 0 cpu; do  # devices
    python val.py --weights $m.pt --device $d # val official
    python val.py --weights runs/train/exp/weights/best.pt --device $d # val custom
    python detect.py --weights $m.pt --device $d  # detect official
    python detect.py --weights runs/train/exp/weights/best.pt --device $d  # detect custom
  done
  python hubconf.py  # hub
  python models/yolo.py --cfg $m.yaml  # build PyTorch model
  python models/tf.py --weights $m.pt  # build TensorFlow model
  python export.py --img 64 --batch 1 --weights $m.pt --include torchscript onnx  # export
done

# %%
# Profile
from utils.torch_utils import profile

m1 = lambda x: x * torch.sigmoid(x)
m2 = torch.nn.SiLU()
results = profile(input=torch.randn(16, 3, 640, 640), ops=[m1, m2], n=100)

# %%
# Evolve
# !python train.py --img 640 --batch 64 --epochs 100 --data coco128.yaml --weights yolov5s.pt --cache --noautoanchor --evolve
# !d=runs/train/evolve && cp evolve.* $d && zip -r evolve.zip $d && gsutil mv evolve.zip gs://bucket  # upload results (optional)

# %%
# VOC
for b, m in zip([64, 48, 32, 16], ['yolov5s', 'yolov5m', 'yolov5l', 'yolov5x']):  # zip(batch_size, model)
  # !python train.py --batch {b} --weights {m}.pt --data VOC.yaml --epochs 50 --cache --img 512 --nosave --hyp hyp.finetune.yaml --project VOC --name {m}

# %%
# TensorRT 
# https://developer.nvidia.com/nvidia-tensorrt-download
# !lsb_release -a  # check system
# %ls /usr/local | grep cuda  # check CUDA
# !wget https://ultralytics.com/assets/TensorRT-8.2.0.6.Linux.x86_64-gnu.cuda-11.4.cudnn8.2.tar.gz  # download
![ -d /content/TensorRT-8.2.0.6/ ] || tar -C /content/ -zxf ./TensorRT-8.2.0.6.Linux.x86_64-gnu.cuda-11.4.cudnn8.2.tar.gz  # unzip
# %pip list | grep tensorrt || pip install /content/TensorRT-8.2.0.6/python/tensorrt-8.2.0.6-cp37-none-linux_x86_64.whl  # install
# %env LD_LIBRARY_PATH=/usr/local/cuda-11.1/lib64:/content/cuda-11.1/lib64:/content/TensorRT-8.2.0.6/lib:/usr/local/nvidia/lib:/usr/local/nvidia/lib64  # add to path

# !python export.py --weights yolov5s.pt --include engine --imgsz 640 640 --device 0
# !python detect.py --weights yolov5s.engine --imgsz 640 640 --device 0
